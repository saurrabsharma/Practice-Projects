# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nelson-wu/employee-attrition-ml/master/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # Observation
# 1.This is our Dataset which contains 1470 rows and 35 columns.
#
# 2.Above project is of HR Analytics based on which we will have to find Attrition of employees.
#
# 3.Since Attrition is our target variable and it contains 2 categories,this is our Binary Classification Problem.
#
# 4.Now we have Attrition as our target variable and rest all are features i.e rest all 34 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Observation
# 1.There are no nulls in our dataset.
#
# 2.Columns with index number 1,2,4,7,11,15,17,21,22 have dtype as object and rest all columns have dtype as int

# %%
#Let's drop duplicates
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (1470, 35)

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df['DistanceFromHome'].value_counts()
# Out:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 15     26
# 18     26
# 26     25
# 25     25
# 20     25
# 28     23
# 19     22
# 14     21
# 12     20
# 17     20
# 22     19
# 13     19
# 21     18
# 27     12
# Name: DistanceFromHome, dtype: int64

# %%
df['EnvironmentSatisfaction'].value_counts()
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
df['HourlyRate'].value_counts()
# Out:
# 66    29
# 98    28
# 42    28
# 48    28
# 84    28
#       ..
# 31    15
# 53    14
# 68    14
# 38    13
# 34    12
# Name: HourlyRate, Length: 71, dtype: int64

# %%
df['NumCompaniesWorked'].value_counts()
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
df['Over18'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
df['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
df['PerformanceRating'].value_counts()
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64

# %%
df['RelationshipSatisfaction'].value_counts()
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %%
df['StandardHours'].value_counts()
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %%
df['YearsWithCurrManager'].value_counts()
# Out:
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 15      5
# 14      5
# 16      2
# Name: YearsWithCurrManager, dtype: int64

# %% [markdown]
# # Observation
# After checking value counts and unique values for all columns we can observe that
#
# 1.Employee Number have all unique values and it will not impact our target variable ,so it can be droped .
#
# 2.Employee Count ,Over18 and Standard Hours, these all columns have constant value so no meaningful insights can be drawn .
# These columns can also be droped off.
#
# 3.Age,DailyRate,DistanceFromHome,HourlyRate,MonthlyIncome,MonthlyRate,NumCompaniesWorked,PercentSalaryHike,TotalWorkYears,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager these columns have numerical data and rest all are having categorical data.

# %%
#Let's drop columns which have no use
df.drop(['EmployeeNumber','EmployeeCount','Over18','StandardHours'],axis=1,inplace=True)
df.shape
# Out:
# (1470, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %% [markdown]
# # Observation
# After seeing the statistics we can observe that
#
# 1.Mean is greater than Median for Age,DistanceFromHome,MonthlyIncome,MonthlyRate,NumCompaniesWorked,PercentSalaryHike,TotalWorkYears,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager. It means these columns have right skewness present.
#
# 2.Max is greater than 75% for most of the columns it means there are some outliers also.
#
# 3.We can see other statistics also

# %%
#lets see how data is distributed for each column
plt.figure(figsize=(15,10))
plotnumber = 1
for col in df[['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]:
    if plotnumber<=13:
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(df[col])
        plt.xlabel(col, fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Observation
# Except for DailyRate,HourlyRate and MonthlyRate ,there is right skewness and outliers in all columns

# %%
#lets see boxplot for each column
plt.figure(figsize=(15,10))
plotnumber = 1
for col in df[['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]:
    if plotnumber<=13:
        ax = plt.subplot(4,4,plotnumber)
        sns.boxplot(df[col])
        plt.xlabel(col, fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Observation
# MonthlyIncome,NumComaniesWorked,TotalWorkingYears,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotionYearsWithCurrManager have some outliers .We will deal with them

# %%
#lets see relation between num column and our target variable
plt.figure(figsize=(15,10))
plotnumber = 1
for col in df[['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]:
    if plotnumber<=13:
        ax = plt.subplot(4,4,plotnumber)
        sns.swarmplot(x=df['Attrition'],y=df[col],data=df)
        plt.xlabel('Attrition', fontsize=20)
        plt.ylabel(col,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Observation
# from here we can observe relation between our numerical column and target variable
#
# 1.in yearswithcurrmanager ,if he has been working for long he is no category and for short period he is in yes
#
# same goes for totalworking years,years at company,yearswithcurrentrole.
#
# for other columns relation can be visulized as well

# %%
#lets encode categorical features using label encoder
from sklearn.preprocessing import LabelEncoder

# %%
for col in df.columns:
    if df[col].dtype == object:
        label = LabelEncoder()
        df[col] = label.fit_transform(df[col])

# %%
#lets see relation between categorical column and our target variable
plt.figure(figsize=(15,10))
plotnumber = 1
for col in df[['BusinessTravel','Department','Education','EducationField','EnvironmentSatisfaction','Gender','JobLevel','JobInvolvement','JobRole','JobSatisfaction','MaritalStatus','OverTime','PerformanceRating','RelationshipSatisfaction','StockOptionLevel','TrainingTimesLastYear','WorkLifeBalance']]:
    if plotnumber<=17:
        ax = plt.subplot(5,4,plotnumber)
        sns.countplot(x=df[col],data=df,hue=df['Attrition'])
        plt.xlabel(col, fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Observation
# From here we can visualize relationship between our categorical column and target variable
#
# Here we can see that all features are impacting in a manner

# %%
#lets see scatter plot for each column
plt.figure(figsize=(15,10))
plotnumber = 1
for col in df[['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]:
    if plotnumber<=13:
        ax = plt.subplot(4,4,plotnumber)
        sns.scatterplot(x=df[col],y=df['Attrition'],hue=df['Attrition'],data=df)
        plt.xlabel(col, fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
#now let's check for skewness
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# ...

# %% [markdown]
# # Observation
# Here i have assumed that skewness should be in range -0.5 to 0.5.
#
# Keeping in mind, above range our column
#
# DisFromHome,MonthlyIncome,NumCompaniesWorked,PercentSalaryHike,TotalWorkingYears,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,yearsWithCurrManager have some skewness.
#
# Let's remove it using transformation method

# %%
#Let's apply log transformation method but before that let's impute 0
df['NumCompaniesWorked']=df['NumCompaniesWorked'].replace(0,df['NumCompaniesWorked'].mean())
df['TotalWorkingYears']=df['TotalWorkingYears'].replace(0,df['TotalWorkingYears'].mean())
df['YearsAtCompany']=df['YearsAtCompany'].replace(0,df['YearsAtCompany'].mean())
df['YearsInCurrentRole']=df['YearsInCurrentRole'].replace(0,df['YearsInCurrentRole'].mean())
df['YearsSinceLastPromotion']=df['YearsSinceLastPromotion'].replace(0,df['YearsSinceLastPromotion'].mean())
df['YearsWithCurrManager']=df['YearsWithCurrManager'].replace(0,df['YearsWithCurrManager'].mean())
#Lets transform using log method
df['DistanceFromHome']=np.log(df['DistanceFromHome'])
df['MonthlyIncome']=np.log(df['MonthlyIncome'])
df['NumCompaniesWorked']=np.log(df['NumCompaniesWorked'])
df['TotalWorkingYears']=np.log(df['TotalWorkingYears'])
df['YearsAtCompany']=np.log(df['YearsAtCompany'])
df['YearsInCurrentRole']=np.log(df['YearsInCurrentRole'])
df['YearsSinceLastPromotion']=np.log(df['YearsSinceLastPromotion'])
df['YearsWithCurrManager']=np.log(df['YearsWithCurrManager'])
df['PercentSalaryHike']=np.log(df['PercentSalaryHike'])

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.246004
# Education                  -0.289681
# EducationField              0.550371
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.286192
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.179307
# OverTime                    0.964489
# PercentSalaryHike           0.494566
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears          -0.879702
# ...

# %%
#lets see how data is distributed for each column
plt.figure(figsize=(15,10))
plotnumber = 1
for col in df[['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]:
    if plotnumber<=13:
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(df[col])
        plt.xlabel(col, fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
#lets see boxplot for each column
plt.figure(figsize=(15,10))
plotnumber = 1
for col in df[['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]:
    if plotnumber<=13:
        ax = plt.subplot(4,4,plotnumber)
        sns.boxplot(df[col])
        plt.xlabel(col, fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
df['YearsSinceLastPromotion'].value_counts()
# Out:
# 0.782876    581
# 0.000000    357
# 0.693147    159
# 1.945910     76
# 1.386294     61
# 1.098612     52
# 1.609438     45
# 1.791759     32
# 2.397895     24
# 2.079442     18
# 2.197225     17
# 2.708050     13
# 2.564949     10
# 2.484907     10
# 2.639057      9
# 2.302585      6
# Name: YearsSinceLastPromotion, dtype: int64

# %%
df['TotalWorkingYears'].value_counts()
# Out:
# 2.302585    202
# 1.791759    125
# 2.079442    103
# 2.197225     96
# 1.609438     88
# 1.945910     81
# 0.000000     81
# 1.386294     63
# 2.484907     48
# 1.098612     42
# 2.708050     40
# 2.772589     37
# 2.397895     36
# 2.564949     36
# 3.044522     34
# 2.833213     33
# 0.693147     31
# 2.639057     31
# 2.995732     30
# 2.890372     27
# 2.944439     22
# 3.135494     22
# 3.091042     21
# 3.178054     18
# 3.218876     14
# 3.332205     14
# 3.258097     14
# 2.422995     11
# 3.367296     10
# 3.433987      9
# 3.465736      9
# 3.401197      7
# 3.496508      7
# 3.295837      7
# 3.583519      6
# 3.526361      5
# 3.610918      4
# 3.555348      3
# 3.688879      2
# 3.637586      1
# Name: TotalWorkingYears, dtype: int64

# %% [markdown]
# # Observation
# 1.After using log transformation tech skewness have reduced in all columns except in TotalWorkingYears and YearsSinceLastPromotion that's why i m not applying any other tech.
#
# 2.Outliers have been removed except in above mentioned columns,now i m not removing them because those values are possible .

# %%
#now let's check for corelation
corr=df.corr()
corr
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.023986   0.076393       -0.004421  -0.003481
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# JobInvolvement            0.029820  -0.130016        0.039062   0.046135
# ...

# %%
#let's plot heatmap
plt.figure(figsize=(22,17))
sns.heatmap(corr,annot=True,fmt='.2g',linewidth=.5)
plt.show()

# %% [markdown]
# # Observation
# From here we can visualize corelation between features and relation with our target variable.for ex
# 1.TotalWorkingYears and Age, TotalWorkingYears and Job Level are in positive corelation
#
# 2.YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager and Job Level are in positive corelation
#
# 3.YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager and MonthlyIncome are in positive corelation
#
# 4.Monthly Income and Job Level are in high corelation and there may be multicollinearity issue.
#
# Let's check it

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=df['JobLevel'],y=df['MonthlyIncome'],data=df)
plt.show()

# %% [markdown]
# # Observation
# Above Plot Shows that there is strong linear relationship between monthly income and job level because as job level increase monthly income also increases.
#
# This will create multicollinearity issue so we can drop one

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2          0.000000
# 1      49          0               1        279           1          2.079442
# 2      37          1               2       1373           1          0.693147
# 3      33          0               1       1392           1          1.098612
# 4      27          0               2        591           1          0.693147
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1          3.135494
# 1466   39          0               2        613           1          1.791759
# 1467   27          0               2        155           1          1.386294
# 1468   49          0               1       1023           2          0.693147
# 1469   34          0               2        628           1          2.079442
#
# ...

# %%
df.drop('Attrition',axis=1).corrwith(df.Attrition)
# Out:
# Age                        -0.159205
# BusinessTravel              0.000074
# DailyRate                  -0.056652
# Department                  0.063991
# DistanceFromHome            0.076393
# Education                  -0.031373
# EducationField              0.026846
# EnvironmentSatisfaction    -0.103369
# Gender                      0.029453
# HourlyRate                 -0.006846
# JobInvolvement             -0.130016
# JobLevel                   -0.169105
# JobRole                     0.067151
# JobSatisfaction            -0.103481
# MaritalStatus               0.162070
# MonthlyIncome              -0.198210
# MonthlyRate                 0.015170
# NumCompaniesWorked         -0.000708
# OverTime                    0.246118
# PercentSalaryHike          -0.017622
# PerformanceRating           0.002889
# RelationshipSatisfaction   -0.045872
# StockOptionLevel           -0.137145
# TotalWorkingYears          -0.227900
# TrainingTimesLastYear      -0.059478
# ...

# %% [markdown]
# # Observation
# from above values we can observe that BusinessTravel,HourlyRate,MonthlyRate,NumCompaniesWorked,PercentSalaryHike,PerformanceRating,YearsSinceLastPromotion are impacting our target variable in very less manner so they can be dropped but we will check other factores also before deleting them

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2          0.000000
# 1      49          0               1        279           1          2.079442
# 2      37          1               2       1373           1          0.693147
# 3      33          0               1       1392           1          1.098612
# 4      27          0               2        591           1          0.693147
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1          3.135494
# 1466   39          0               2        613           1          1.791759
# 1467   27          0               2        155           1          1.386294
# 1468   49          0               1       1023           2          0.693147
# 1469   34          0               2        628           1          2.079442
#
# ...

# %%
#let's separate features and label
X=df.drop(columns=['Attrition'],axis=1)
y=df['Attrition']

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2          0.000000
# 1      49          0               1        279           1          2.079442
# 2      37          1               2       1373           1          0.693147
# 3      33          0               1       1392           1          1.098612
# 4      27          0               2        591           1          0.693147
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1          3.135494
# 1466   39          0               2        613           1          1.791759
# 1467   27          0               2        155           1          1.386294
# 1468   49          0               1       1023           2          0.693147
# 1469   34          0               2        628           1          2.079442
#
# ...

# %%
X.shape
# Out:
# (1470, 30)

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
#now lets standarize our dataset
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
X_scaled=scalar.fit_transform(df[['Age','DailyRate','HourlyRate','MonthlyRate']])

X_scaled
# Out:
# array([[ 0.4463504 ,  0.74252653,  1.38313827,  0.72601994],
#        [ 1.32236521, -1.2977746 , -0.24067677,  1.48887614],
#        [ 0.008343  ,  1.41436324,  1.28472523, -1.67484086],
#        ...,
#        [-1.08667552, -1.60518328,  1.03869265, -1.28441814],
#        [ 1.32236521,  0.54667746, -0.14226374, -0.15039333],
#        [-0.32016256, -0.43256792,  0.79266007, -0.57412425]])

# %%
X.drop(columns=['Age','DailyRate','HourlyRate','MonthlyRate'],axis=1,inplace=True)
X
# Out:
#       BusinessTravel  Department  DistanceFromHome  Education  EducationField  \
# 0                  2           2          0.000000          2               1
# 1                  1           1          2.079442          1               1
# 2                  2           1          0.693147          2               4
# 3                  1           1          1.098612          4               1
# 4                  2           1          0.693147          1               3
# ...              ...         ...               ...        ...             ...
# 1465               1           1          3.135494          2               3
# 1466               2           1          1.791759          1               3
# 1467               2           1          1.386294          3               1
# 1468               1           2          0.693147          3               3
# 1469               2           1          2.079442          3               3
#
# ...

# %%
X=pd.concat([X,pd.DataFrame(X_scaled)],axis=1)
X
# Out:
#       BusinessTravel  Department  DistanceFromHome  Education  EducationField  \
# 0                  2           2          0.000000          2               1
# 1                  1           1          2.079442          1               1
# 2                  2           1          0.693147          2               4
# 3                  1           1          1.098612          4               1
# 4                  2           1          0.693147          1               3
# ...              ...         ...               ...        ...             ...
# 1465               1           1          3.135494          2               3
# 1466               2           1          1.791759          1               3
# 1467               2           1          1.386294          3               1
# 1468               1           2          0.693147          3               3
# 1469               2           1          2.079442          3               3
#
# ...

# %%
X.rename(columns={0:'Age',1:'DailyRate',2:'HourlyRate',3:'MonthlyRate'},inplace=True)
X
# Out:
#       BusinessTravel  Department  DistanceFromHome  Education  EducationField  \
# 0                  2           2          0.000000          2               1
# 1                  1           1          2.079442          1               1
# 2                  2           1          0.693147          2               4
# 3                  1           1          1.098612          4               1
# 4                  2           1          0.693147          1               3
# ...              ...         ...               ...        ...             ...
# 1465               1           1          3.135494          2               3
# 1466               2           1          1.791759          1               3
# 1467               2           1          1.386294          3               1
# 1468               1           2          0.693147          3               3
# 1469               2           1          2.079442          3               3
#
# ...

# %% [markdown]
# # Observation
# Now let's check vif to see multicollinearity issue

# %%
#let's drop one of the feature
X.drop('JobLevel',axis=1,inplace=True)
X
# Out:
#       BusinessTravel  Department  DistanceFromHome  Education  EducationField  \
# 0                  2           2          0.000000          2               1
# 1                  1           1          2.079442          1               1
# 2                  2           1          0.693147          2               4
# 3                  1           1          1.098612          4               1
# 4                  2           1          0.693147          1               3
# ...              ...         ...               ...        ...             ...
# 1465               1           1          3.135494          2               3
# 1466               2           1          1.791759          1               3
# 1467               2           1          1.386294          3               1
# 1468               1           2          0.693147          3               3
# 1469               2           1          2.079442          3               3
#
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(X,i) for i in range(X.shape[1])]
vif['features']=X.columns
#let's check for value
vif
# Out:
#            vif                  features
# 0     6.888244            BusinessTravel
# 1    12.833589                Department
# 2     3.742378          DistanceFromHome
# 3     9.545335                 Education
# 4     3.899413            EducationField
# 5     7.218958   EnvironmentSatisfaction
# 6     2.530980                    Gender
# 7    15.359257            JobInvolvement
# 8     8.035296                   JobRole
# 9     7.179021           JobSatisfaction
# 10    5.885409             MaritalStatus
# 11  170.395320             MonthlyIncome
# 12    3.353208        NumCompaniesWorked
# 13    1.432707                  OverTime
# 14  265.506833         PercentSalaryHike
# 15  163.993649         PerformanceRating
# 16    7.327250  RelationshipSatisfaction
# 17    3.339885          StockOptionLevel
# 18   29.781263         TotalWorkingYears
# 19    5.742851     TrainingTimesLastYear
# 20   16.289729           WorkLifeBalance
# 21   12.104770            YearsAtCompany
# ...

# %% [markdown]
# # Observation
# The vif value for some columns is greater than 10, so let's delete them to avoid multicollinearity issue

# %%
X.drop(columns=['Department','JobInvolvement','MonthlyIncome','TotalWorkingYears','WorkLifeBalance','PercentSalaryHike','PerformanceRating','YearsAtCompany','YearsInCurrentRole','YearsWithCurrManager'],axis=1,inplace=True)
X
# Out:
#       BusinessTravel  DistanceFromHome  Education  EducationField  \
# 0                  2          0.000000          2               1
# 1                  1          2.079442          1               1
# 2                  2          0.693147          2               4
# 3                  1          1.098612          4               1
# 4                  2          0.693147          1               3
# ...              ...               ...        ...             ...
# 1465               1          3.135494          2               3
# 1466               2          1.791759          1               3
# 1467               2          1.386294          3               1
# 1468               1          0.693147          3               3
# 1469               2          2.079442          3               3
#
#       EnvironmentSatisfaction  Gender  JobRole  JobSatisfaction  \
# 0                           2       0        7                4
# ...

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(X,i) for i in range(X.shape[1])]
vif['features']=X.columns
#let's check for value
vif
# Out:
#          vif                  features
# 0   6.184548            BusinessTravel
# 1   3.575460          DistanceFromHome
# 2   8.398033                 Education
# 3   3.760877            EducationField
# 4   6.537074   EnvironmentSatisfaction
# 5   2.443030                    Gender
# 6   4.197901                   JobRole
# 7   6.451471           JobSatisfaction
# 8   5.351510             MaritalStatus
# 9   2.650896        NumCompaniesWorked
# 10  1.421986                  OverTime
# 11  6.562764  RelationshipSatisfaction
# 12  3.061887          StockOptionLevel
# 13  5.324680     TrainingTimesLastYear
# 14  2.560089   YearsSinceLastPromotion
# 15  1.228503                       Age
# 16  1.010860                 DailyRate
# 17  1.014163                HourlyRate
# 18  1.010998               MonthlyRate

# %% [markdown]
# # lets use selectkbest feature selection technique

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
best=SelectKBest(score_func=f_classif,k=8)
fit=best.fit(X,y)
df_scores=pd.DataFrame(fit.scores_)
df_columns=pd.DataFrame(X.columns)
feature=pd.concat([df_columns,df_scores],axis=1)
feature.columns=['feat_name','Score']
print(feature.nlargest(19,'Score'))
# Out:
#                    feat_name      Score
# 10                  OverTime  94.656457
# 8              MaritalStatus  39.599763
# 15                       Age  38.175887
# 12          StockOptionLevel  28.140501
# 7            JobSatisfaction  15.890004
# 4    EnvironmentSatisfaction  15.855209
# 1           DistanceFromHome   8.617346
# 6                    JobRole   6.649672
# 13     TrainingTimesLastYear   5.211646
# 16                 DailyRate   4.726640
# 11  RelationshipSatisfaction   3.095576
# 2                  Education   1.446308
# 5                     Gender   1.274587
# 3             EducationField   1.058726
# 18               MonthlyRate   0.337916
# 17                HourlyRate   0.068796
# 14   YearsSinceLastPromotion   0.020554
# 9         NumCompaniesWorked   0.000735
# 0             BusinessTravel   0.000008

# %% [markdown]
# # Observation
# Based on above results i m deleting last four columns because yhere impact is very less

# %%
X.drop(columns=['HourlyRate','YearsSinceLastPromotion','NumCompaniesWorked','BusinessTravel'],axis=1,inplace=True)
X
# Out:
#       DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0             0.000000          2               1                        2
# 1             2.079442          1               1                        3
# 2             0.693147          2               4                        4
# 3             1.098612          4               1                        4
# 4             0.693147          1               3                        1
# ...                ...        ...             ...                      ...
# 1465          3.135494          2               3                        3
# 1466          1.791759          1               3                        4
# 1467          1.386294          3               1                        2
# 1468          0.693147          3               3                        4
# 1469          2.079442          3               3                        2
#
#       Gender  JobRole  JobSatisfaction  MaritalStatus  OverTime  \
# ...

# %%
y.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# # Observation
# Here our classes are imbalanced so let's balance our classes using SMOTE method

# %%
from imblearn.over_sampling import SMOTE

# %%
SM=SMOTE()
X,y=SM.fit_resample(X,y)

# %%
y.value_counts()
# Out:
# 1    1233
# 0    1233
# Name: Attrition, dtype: int64

# %%
#creating training and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=154)

# %% [markdown]
# # Modelling

# %%
#import lib
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.svm import SVC
import xgboost as xgb

# %%
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print("=======Train Result======")
        print(f"Accuracy Score:{accuracy_score(y_train,y_pred)*100:.2f}%")
    elif train==False:
        pred=clf.predict(x_test)
        print("\n===Test Result====")
        print(f"Accuracy Score:{accuracy_score(y_test,pred)*100:.2f}%")
        
        print('\n\nTest Classification Report\n',classification_report(y_test,pred,digits=2))

# %%
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
metric_score(log,x_train,x_test,y_train,y_test,train=True)
metric_score(log,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:77.56%
#
# ===Test Result====
# Accuracy Score:77.96%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       314
#            1       0.77      0.78      0.78       303
#
#     accuracy                           0.78       617
#    macro avg       0.78      0.78      0.78       617
# weighted avg       0.78      0.78      0.78       617

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
metric_score(knn,x_train,x_test,y_train,y_test,train=True)
metric_score(knn,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:89.24%
#
# ===Test Result====
# Accuracy Score:84.76%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.97      0.73      0.83       314
#            1       0.77      0.97      0.86       303
#
#     accuracy                           0.85       617
#    macro avg       0.87      0.85      0.85       617
# weighted avg       0.87      0.85      0.85       617

# %%
tree=DecisionTreeClassifier()
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
metric_score(tree,x_train,x_test,y_train,y_test,train=True)
metric_score(tree,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:100.00%
#
# ===Test Result====
# Accuracy Score:80.39%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80       314
#            1       0.79      0.82      0.80       303
#
#     accuracy                           0.80       617
#    macro avg       0.80      0.80      0.80       617
# weighted avg       0.80      0.80      0.80       617

# %%
bag=BaggingClassifier()
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
metric_score(bag,x_train,x_test,y_train,y_test,train=True)
metric_score(bag,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:99.30%
#
# ===Test Result====
# Accuracy Score:87.20%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       314
#            1       0.88      0.86      0.87       303
#
#     accuracy                           0.87       617
#    macro avg       0.87      0.87      0.87       617
# weighted avg       0.87      0.87      0.87       617

# %%
rand=RandomForestClassifier()
rand.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
metric_score(rand,x_train,x_test,y_train,y_test,train=True)
metric_score(rand,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:100.00%
#
# ===Test Result====
# Accuracy Score:89.47%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       314
#            1       0.89      0.89      0.89       303
#
#     accuracy                           0.89       617
#    macro avg       0.89      0.89      0.89       617
# weighted avg       0.89      0.89      0.89       617

# %%
ada=AdaBoostClassifier()
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
metric_score(ada,x_train,x_test,y_train,y_test,train=True)
metric_score(ada,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:83.02%
#
# ===Test Result====
# Accuracy Score:80.55%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81       314
#            1       0.79      0.82      0.80       303
#
#     accuracy                           0.81       617
#    macro avg       0.81      0.81      0.81       617
# weighted avg       0.81      0.81      0.81       617

# %%
grad=GradientBoostingClassifier()
grad.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
metric_score(grad,x_train,x_test,y_train,y_test,train=True)
metric_score(grad,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:90.64%
#
# ===Test Result====
# Accuracy Score:86.39%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87       314
#            1       0.86      0.86      0.86       303
#
#     accuracy                           0.86       617
#    macro avg       0.86      0.86      0.86       617
# weighted avg       0.86      0.86      0.86       617

# %%
support=SVC()
support.fit(x_train,y_train)
# Out:
# SVC()

# %%
metric_score(support,x_train,x_test,y_train,y_test,train=True)
metric_score(support,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:84.21%
#
# ===Test Result====
# Accuracy Score:82.66%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83       314
#            1       0.82      0.83      0.82       303
#
#     accuracy                           0.83       617
#    macro avg       0.83      0.83      0.83       617
# weighted avg       0.83      0.83      0.83       617

# %%
model=xgb.XGBClassifier()
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
metric_score(model,x_train,x_test,y_train,y_test,train=True)
metric_score(model,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:100.00%
#
# ===Test Result====
# Accuracy Score:90.60%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       314
#            1       0.90      0.91      0.91       303
#
#     accuracy                           0.91       617
#    macro avg       0.91      0.91      0.91       617
# weighted avg       0.91      0.91      0.91       617

# %% [markdown]
# # Observation
# From Accuracy Score of all models ,Xgboost model is giving best score i.e of 90.60%
#
# Let's validate our score using cross val tech

# %%
from sklearn.model_selection import cross_val_score

# %%
#lets check for log model
pred=log.predict(x_test)
score=cross_val_score(log,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred)-score)
# Out:
# Difference is ; 0.02001598451657005

# %%
#now lets check for knn model
pred2=knn.predict(x_test)
score2=cross_val_score(knn,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred2)-score2)
# Out:
# Difference is ; 0.009843708945559637

# %%
#now lets check for decision tree model
pred3=tree.predict(x_test)
score3=cross_val_score(tree,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred3)-score3)
# Out:
# Difference is ; 0.013504558008271883

# %%
#now lets check for bagging model
pred4=bag.predict(x_test)
score4=cross_val_score(bag,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred4)-score4)
# Out:
# Difference is ; 0.021953300577869483

# %%
#now lets check for random forest model
pred5=rand.predict(x_test)
score5=cross_val_score(rand,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred5)-score5)
# Out:
# Difference is ; -0.00319770190098434

# %%
#now lets check for ada boost model
pred6=ada.predict(x_test)
score6=cross_val_score(ada,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred6)-score6)
# Out:
# Difference is ; 0.0029401363110742595

# %%
#now lets check for gradient boost model
pred7=grad.predict(x_test)
score7=cross_val_score(grad,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred7)-score7)
# Out:
# Difference is ; 0.016278722660691525

# %%
#now lets check for SVC model
pred8=support.predict(x_test)
score8=cross_val_score(support,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred8)-score8)
# Out:
# Difference is ; 0.01591184116392874

# %%
#now lets check for xgb model
pred9=model.predict(x_test)
score9=cross_val_score(support,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,pred9)-score9)
# Out:
# Difference is ; 0.09532837276846684

# %% [markdown]
# # Observation
# Based on our cross val score ,adaboostclassifier model is performing best.
#
# Lets use hyper parameter tuning to increase our score and find best parameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={
       'n_estimators':[20,30,40,50,60,70,80,90],
       'random_state':[10,20,30,40,50,60],
        'learning_rate':[1,2,3,4,5,6,7,8,9]
       } 
grd=GridSearchCV(ada,param_grid=params)
grd.fit(x_train,y_train)
print('Best_Parameters ',grd.best_params_)
# Out:
# Best_Parameters  {'learning_rate': 1, 'n_estimators': 80, 'random_state': 10}

# %%
final_model=grd.best_estimator_
final_model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=1, n_estimators=80, random_state=10)

# %%
metric_score(final_model,x_train,x_test,y_train,y_test,train=True)
metric_score(final_model,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======Train Result======
# Accuracy Score:84.15%
#
# ===Test Result====
# Accuracy Score:82.50%
#
#
# Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83       314
#            1       0.82      0.83      0.82       303
#
#     accuracy                           0.82       617
#    macro avg       0.82      0.83      0.82       617
# weighted avg       0.83      0.82      0.82       617

# %%
# lets check cross val for our final SVC model
final=ada.predict(x_test)
final_score=cross_val_score(ada,X,y,cv=5).mean()
print("Difference is ;", accuracy_score(y_test,final)-final_score)
# Out:
# Difference is ; 0.0029401363110742595

# %% [markdown]
# # Observation
# After using tuning tech our score i.e accuracy score got increased to 82.50 and this is our best model
#
# now let's check roc auc score

# %%
from sklearn.metrics import roc_curve,roc_auc_score

# %%
fpr,tpr,thresholds=roc_curve(y_test,final)

# %%
print('threshold=',thresholds)
print('True Positive Rate=',tpr)
print('False Positive Rate=',fpr)
# Out:
# threshold= [2 1 0]
# True Positive Rate= [0.         0.81518152 1.        ]
# False Positive Rate= [0.         0.20382166 1.        ]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Let's check auc score
auc_score=roc_auc_score(y_test,final)
print(auc_score*100)
# Out:
# 80.56799310504299

# %%
#now lets save model using joblib
import joblib

# %%
joblib.dump(final_model,'HRAnalyticsModel.obj')
# Out:
# ['HRAnalyticsModel.obj']
